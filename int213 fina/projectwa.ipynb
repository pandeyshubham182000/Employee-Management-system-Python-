# %%
# EMPLOYEE RECURIMENT SYSTEM  FULLY WORKING MAIN PROJECTY HAI Y  ====>>>
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
from csv import DictWriter as d_w
from csv import DictReader as d_r
import os
import datetime
import random as rd
win=tk.Tk()
win.title("✔️ Log_In")
win.configure(background="orange")
win.geometry("500x400+50+50")
win.resizable(0,0)
#to add image====>
file=tk.PhotoImage(file="2.gif")
quote=tk.Label(win,image=file,height=160,width=300,borderwidth=8,relief="raised")
quote.grid(row=0,column=0,sticky=tk.W,padx=70,pady=5)
quote1=tk.Label(win,text="SHUBHAM METACOMPANY",height=1,width=40,borderwidth=8,relief='groove',font=("Apple Chancery",20),foreground="red")
quote1.grid(row=0,column=0,sticky=tk.W,padx=7)
# LABEL =>
lname=tk.StringVar()
lname=ttk.Label(win,text="🆎 USERNAME",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=15 )
lname.grid(row=2, column=0, sticky=tk.W,pady=8,padx=2)
# ENTERY =>
lname_var=tk.StringVar()
lname_entery=tk.Entry(win,textvariable=lname_var,font=("Rockwell",15),borderwidth=8,relief="sunken")
lname_entery.grid(row=4,column=0,sticky=tk.W,padx=19)
lname_entery.focus()
# LABEL =>
lpassword=ttk.Label(win,text="🔐 PASSWORD",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=15 )
lpassword.grid(row=2, column=0, sticky=tk.W,pady=8,padx=303)
# ENTERY =>
lpassword_var=tk.StringVar()
lpassword_entery=tk.Entry(win,textvariable=lpassword_var,font=("Rockwell",15),borderwidth=8,relief="sunken")
lpassword_entery.grid(row=4,column=0,sticky=tk.W,padx=270)
#msg box ==>
mb.showinfo("🗣 carefull".upper(),"👉🏽 username".title()+" is Your Name  \n"+"👉🏽 password is your contact number".title())
# BUTTON ==>
def login():
    flname=lname_var.get().upper()
    flpassword=lpassword_var.get()
    if flname=="" or flpassword=="":
        mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
    else:
        lpassword_entery.delete(0,tk.END)
        lpassword_entery.focus()
        #read from csv==>
        with open('register.csv','r') as fi:
            c=d_r(fi)
            l=False
            for row in c:
                if row['NAME']==flname and row['PASSWORD']==flpassword:
                    mb.showinfo("☑️ STATUS","Namaste 🙏 "+flname +" Log-In Successful !!!! ")
                    l=True
                     #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                     # MAIN WINDOW ===>
                    top2=tk.Toplevel()
                    top2.title(" 🇮🇳 COUNTRY FIRST 🛠 SHUBHAM METACOMPANY")
                    top2.configure(background="orange")
                    top2.geometry("1200x670+50+0")
                    top2.resizable(0,0)
                    #file=tk.PhotoImage(file="2.gif")
                    vote=tk.Label(top2,image=file,height=160,width=300,borderwidth=8,relief="raised")
                    vote.grid(row=0,column=0,sticky=tk.W,padx=420,pady=5)
                    quote2=tk.Label(top2,text="⛪️   SHUBHAM METACOMPANY   🛠",height=1,width=70,borderwidth=8,relief='groove',font=("Apple Chancery",30),foreground="red")
                    quote2.grid(row=0,column=0,sticky=tk.W,padx=7)
                     # LABEL left===>
                    name=tk.Label(top2,text="🧰 सहज रोजगार ", font=("Rockwell",30),width=20,height=2,borderwidth=8,relief='raised')
                    name.grid(row=1,column=0,sticky=tk.W, pady=100)
                    name=tk.Label(top2,text="🧑‍🦰 WELCOME "+flname, font=("Rockwell",15),width=30,height=1,borderwidth=8,relief='raised')
                    name.grid(row=1,column=0,sticky=tk.W,padx=850, pady=40)
                    #aplly button coded==>
                    def KEYG():
                        top7=tk.Toplevel()
                        top7.title(" 🇮🇳 COUNTRY FIRST 🛠 SHUBHAM METACOMPANY")
                        top7.configure(background="orange")
                        top7.geometry("500x400+50+50")
                        top7.resizable(0,0)
                        la1=tk.Label(top7,text="APPLICATION FORM",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=35 )
                        la1.grid(row=0,column=0,sticky=tk.W,padx=5,pady=5)
                         # LABEL =>
                        lname1=ttk.Label(top7,text="🌴 YOUR EMAIL",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname1.grid(row=1, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var1=tk.StringVar()
                        lname_entery1=tk.Entry(top7,textvariable=lname_var1,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery1.grid(row=1,column=0,sticky=tk.W,pady=5,padx=260)
                        lname_entery1.focus()
                         # LABEL =>
                        lname2=tk.StringVar()
                        lname2=ttk.Label(top7,text="🚩 COMPANY EMAIL",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname2.grid(row=2, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var2=tk.StringVar()
                        lname_entery2=tk.Entry(top7,textvariable=lname_var2,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery2.grid(row=2,column=0,sticky=tk.W,padx=260)
                         # LABEL =>
                        lname3=ttk.Label(top7,text=" 📌 JOB - ID",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname3.grid(row=3, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        job_id_var1 =tk.StringVar()
                        job_id_var1=tk.Entry(top7,textvariable=job_id_var1,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        job_id_var1.grid(row=3,column=0,sticky=tk.W,padx=260)
                        # LABEL =>
                        lname4=tk.StringVar()
                        lname4=ttk.Label(top7,text=" 📕 POST",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname4.grid(row=4, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var4=tk.StringVar()
                        lname_entery4=tk.Entry(top7,textvariable=lname_var4,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery4.grid(row=4,column=0,sticky=tk.W,padx=260) 
                         #button
                        def app():
                            cemail=lname_var2.get()   #recieve address
                            semail=lname_var1.get()   #sender email
                            jobid1=job_id_var1.get()
                            post1=lname_var4.get()
                            import re
                            regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
                            a=cemail
                            b=False
                            if(re.search(regex,a)):
                                b=True
                            else:
                                b="fail"
                            if cemail=="" or semail=="" or jobid1=="" or post1=="":
                                mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
                            elif b=="fail":
                                mb.showerror("⚠️ ERROR","such email-id does not exist !!! ".title())
                            else:
                                from email.message import EmailMessage
                                import os
                                import smtplib
                                import imghdr
                                from tkinter import filedialog as fd
                                eid="pandeykedarnath18200@gmail.com"
                                epass="Shubh2018@4662"
                                b=fd.askopenfile(initialdir="/")
                                c=b.name
                                str(c)
                                msg=EmailMessage()
                                msg['subject']="Job Application"
                                msg['from']="pandeykedarnath18200@gmail.com"
                                msg['to']=str(cemail)
                                msg.set_content("Sir kindly accept my resume for my job profile \n REPLY => "+semail +" \n JOB-ID => " + jobid1 + "\nPOST => "+ post1)
                                with open(c,'rb') as m:
                                    file_data=m.read()
                                    file_type=imghdr.what(m.name)
                                    file_name=m.name
                                msg.add_attachment(file_data,maintype='image',subtype=file_type,filename=file_name)
                                with smtplib.SMTP_SSL('smtp.gmail.com',465) as smtp:
                                    smtp.login(eid,epass)
                                    print("log ")
                                    smtp.send_message(msg)
                                    print("sent")
                                    import mysql.connector
                                    conn=mysql.connector.connect(host="localhost",username="root",password="shubh2017@4662",database="job_applied")
                                    my_cursor=conn.cursor()
                                    #query="CREATE TABLE job (SENDER_EMAIL varchar(50), COMPANY_EMAIL varchar(50),JOB_ID varchar(20),POST varchar(50))"
                                    query="INSERT INTO job(SENDER_EMAIL, COMPANY_EMAIL, JOB_ID, POST) VALUES(%s, %s, %s, %s)"
                                    values=(semail,cemail,jobid1,post1)
                                    my_cursor.execute(query,values)
                                     #print(my_cursor.fetchall())
                                    conn.commit()
                                    conn.close()
                                    mb.showinfo("🖌 STATUS", "Job🗂Applied")                      
                        but1=tk.Button(top7,text="Upload Resume & Apply",width=40,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",15),command=app)
                        but1.grid(row=5,column=0,sticky=tk.W,pady=10,padx=30)
                    apply=tk.Button(top2,text="APLLY ✍🏻 JOB".title(),height=1,width=15,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",20),command=KEYG)
                    apply.grid(row=1,column=0,sticky=tk.W,padx=510,pady=100)
                     ############################################################
                     #button ===>
                    def post_job():
                        top1=tk.Toplevel()
                        top1.title("🏅 post a job".title())
                        top1.configure(background="orange")
                        top1.geometry("500x650+50+0")
                         #top1.resizable(0,0) 
                         # TITLE LABEL =>
                        title=tk.Label(top1,text="🔱 POST A JOB ",width=25,borderwidth=5,relief="sunken", font=("Apple Chancery",28))
                        title.grid(row=0,column=0,sticky=tk.W,padx=30, pady=5)
                        title.configure(foreground="red")
                         #LABEL ==>
                        label=['🏛 COMPANY', '🪑 POST','👨‍🎓 ELIGIBILITY','Ⓜ️ SALARY','☏ E-MAIL & Mob.','🧜‍ CATEGORY']
                        a=1
                        for i in range(len(label)): 
                            cur_l="label"+ str(i) #label 1, label2, etc
                            cur_l=tk.Label(top1, text=label[i],borderwidth=8,relief="raised",font=("Rockwell",20),width=20,height=2)
                            cur_l.grid(row=i+a, column=0, sticky=tk.W, padx=2,pady=5)
                            cur_l.configure(foreground="blue")
                            a+=1
                         #ENTERY==>
                        user_info1={
                                   'company':tk.StringVar(),
                                   'post':tk.StringVar(),
                                   'eligibility':tk.StringVar(),
                                   'salary':tk.StringVar(),    #var section
                                   'contact':tk.StringVar(),
                            }
                        a=1
                        j=0
                        for i in user_info1:
                            cur_entery='entery'+i   #enteryname, enteryaddress, etc
                            cur_entery=tk.Entry(top1, width=25,textvariable=user_info1[i], font=("Rockwell",15),borderwidth=8,relief="sunken")
                            cur_entery.grid(row=j+a, column=0,padx=240,)
                            cur_entery.configure(foreground="red")
                            a+=1
                            j+=1
                            if(i=='NAME'):
                                cur_entery.focus()
                         # COMBOBOX ==>
                        group_var=tk.StringVar()
                        group_entery=ttk.Combobox(top1,width=25,state='readonly',font=("Rockwell",15),textvariable=group_var)
                        group_entery['values']=('⌨️ data entery'.title(), '📞 back office'.title(),'🎥 iT sector'.title(),
                                                '📺 non technical'.title(),'💻 technical'.title(),'👮‍administrative'.title(),
                                                '⛏ grade d'.title(),'🔨 construction'.title(),'⚔️ trainer'.title())
                        group_entery.current(0)
                        group_entery.grid(row=11,column=0,padx=22) 
                        #____________________
                        mb.showinfo("🗣 carefull".upper()," 🧓🏻 COMPANY LIKE ABC \n".title()
                                    +" 🆎 POST BE LIKE director \n".title()+"👨‍🎓 eligibility BE LIke education/experience \n".title()
                                    +" 🌏 salary BE LIKE 45k p.A \n".title()+" 🌏 contact BE LIKE 7256362598 AND E-MAIL".title())
                          #BUTTON ACTION ===>
                        def post():
                            company_p= user_info1['company'].get().upper()
                            post_p= user_info1['post'].get().upper()
                            eligibility_p= user_info1['eligibility'].get().title()
                            salary_p= user_info1['salary'].get()
                            contact_p=user_info1['contact'].get()
                            categorey_p=group_var.get().title()
                            tday=datetime.date.today()                            
                            if company_p==""or post_p=="" or eligibility_p=="" or salary_p=="":
                                mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
                            else:
                                mb.showinfo("☑️ STATUS","Congratulations 🙏"+company_p+" Job Posted !!!! ")
                                #=================
                                def w():
                                    write=d_w(f,fieldnames=['COMPANY','JOB-ID','POST','ELIGIBILITY','SALARY','CONTACT','CATEGOREY','DATE'])
                                    if os.stat('CONSTRUCTION_JOBS.csv').st_size==0:
                                        write.writeheader()
                                    write.writerow({
                                                    'JOB-ID':rd.randint(1234,56789),
                                                    'COMPANY':company_p,
                                                    'POST':post_p,
                                                    'ELIGIBILITY':eligibility_p,
                                                    'SALARY':salary_p,
                                                    'CONTACT':contact_p,
                                                    'CATEGOREY':categorey_p,
                                                    'DATE':tday
                                       })           
                                #===================
                                #how to write with csv file===>
                                #=====================
                                if categorey_p=="⌨️ Data Entery":
                                    with open('DATA_ENTERY_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="📞 Back Office":
                                    with open('BACK_OFFICE_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="🎥 It Sector":
                                    with open('IT_SECTOR_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="📺 Non Technical":
                                    with open('NON_TECHNICAL_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="💻 Technical":
                                    with open('TECHNICAL_JOBS.csv','a') as f:
                                        w()                    
                                elif categorey_p=="👮‍Administrative":
                                    with open('ADMINISTRATIVE_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="⛏ Grade D":
                                    with open('GRADE_D_JOBS.csv','a') as f:
                                        w()  
                                elif categorey_p=="🔨 Construction":
                                    with open('CONSTRUCTION_JOBS.csv','a') as f:
                                        w()
                                else:
                                    with open('TRAINER_JOBS.csv','a') as f:
                                        w()
                          # BUTTON ==>
                        submit_p=tk.Button(top1,text="👍🏾 POST",height=1,width=25,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=post)
                        submit_p.grid(row=12,column=0,sticky=tk.W,padx=100, pady=30)
                        #==================================================  
                    post_job=tk.Button(top2,text="POST JOB HERE  ➤".title(),height=1,width=15,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",20),command=post_job)
                    post_job.grid(row=1,column=0,sticky=tk.W,padx=290,pady=100)
                     #======================
                     #LAST KI BUTTON ====>
                     #===========================================
                    def KEYA():
                        os.system("open DATA_ENTERY_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 DATA ENTERY".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYA)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=3,pady=5)

                    def KEYB():
                        os.system("open BACK_OFFICE_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 BACK OFFICE ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYB)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=3,pady=5)

                    def KEYC():
                        os.system("open IT_SECTOR_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 IT SECTOR ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYC)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=3,pady=5)
                     #===========================================
                    def KEYD():
                        os.system("open NON_TECHNICAL_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 NON TECHNICAL ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYD)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=430,pady=0)

                    def KEYE():
                        os.system("open TECHNICAL_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 TECHNICAL ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYE)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=430,pady=5)

                    def KEYF():
                        os.system("open ADMINISTRATIVE_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 ADMINSTRATIVE".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYF)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=430,pady=5)
                    #============================================
                    def KEYG():
                        os.system("open GRADE_D_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 GRADE D".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYG)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=849,pady=0)

                    def KEYH():
                        os.system("open CONSTRUCTION_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 CONSTRUCTION ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYH)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=849,pady=5)

                    def KEYI():
                        os.system("open TRAINER_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 TRAINER".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYI)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=849,pady=5)                     
                    #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
            if l==False:
                mb.showinfo("☑️ STATUS","Enter 🕹 correct details".title())
submit=tk.Button(win,text="✔️ Log-In",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=login)
submit.grid(row=5,column=0,sticky=tk.W,padx=30,pady=60)
######################### BUTTON REGISTRATON ===>
def register():
    wind=tk.Toplevel()
    wind.title("📓 REGISTER")
    wind.configure(background="orange")
    wind.geometry("305x600+570+50")
    wind.resizable(0,0)
    #to add image 
    # TITLE LABEL =>
    title=ttk.Label(wind,text="REGISTER HERE !!! ",borderwidth=5,relief="flat", font=("Apple Chancery",28))
    title.grid(row=0,column=0, pady=5)
    title.configure(background="blue",foreground="red")
    #LABEL ==>
    label=['🧓🏻 FULL NAME', '🆎 E-MAIL', '☏ CONTACT','🗝 PASSWORD','🧜‍ GENDER']
    a=1
    for i in range(len(label)):
        cur_l="label"+ str(i) #label 1, label2, etc
        cur_l=ttk.Label(wind, text=label[i],borderwidth=8,relief="raised",font=("Rockwell",20),width=15)
        cur_l.grid(row=i+a, column=0, sticky=tk.W, padx=2,pady=5)
        cur_l.configure(foreground="blue")
        a+=1
    #ENTERY==>
    user_info={
        'NAME':tk.StringVar(),
        'E-MAIL':tk.StringVar(),
        'CONTACT':tk.StringVar(),
        'PASSWORD':tk.StringVar(),    #var section
      }
    c=2
    j=0
    for i in user_info:
        cur_entery='entery'+i   #enteryname, enteryaddress, etc
        cur_entery=tk.Entry(wind, width=28,textvariable=user_info[i], font=("Rockwell",15),borderwidth=8,relief="sunken")
        cur_entery.grid(row=c+j, column=0,padx=24)
        cur_entery.configure(foreground="red")
        c+=1
        j+=1
        if(i=='NAME'):
            cur_entery.focus()
    # COMBOBOX ==>
    gender_var=tk.StringVar()
    gender=ttk.Combobox(wind,width=28,state='readonly',font=("Rockwell",15),textvariable=gender_var)
    gender['values']=('Male', 'Female','Other')
    gender.current(0)
    gender.grid(row=10,column=0,padx=22)
    #BUTTON ACTION ===>
    def action():
        full_name= user_info['NAME'].get().upper()
        email= user_info['E-MAIL'].get()
        contact= user_info['CONTACT'].get()
        str(contact)
        password= user_info['PASSWORD'].get()
        gender=gender_var.get().title()
        import re
        regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
        a=email
        b=False
        if(re.search(regex,a)):
            b=True
        else:
            b="fail"
        if full_name==""or email=="" or contact=="" or password=="":
            mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
        elif full_name.isdigit()==True or contact.isdigit()==False:
            mb.showwarning("☠️ WARNING ", "👉🏽 name 🗣 must be alphabatic \n 👉🏽 contact must be numeric".title())
        elif b=="fail":
            mb.showerror("⚠️ ERROR","INVALID EMAIL")
        else:            
            #how to write with csv file===>
            with open('register.csv','a') as f:
                write=d_w(f,fieldnames=['NAME','EMAIL','CONTACT','PASSWORD','GENDER'])
                if os.stat('register.csv').st_size==0:
                    write.writeheader()
                write.writerow({
                    'NAME':full_name,
                    'EMAIL':email,
                    'CONTACT':contact,
                    'PASSWORD':password,
                    'GENDER':gender
                  })
            cur_entery.delete(0,tk.END)
             #mail after regist 
            import smtplib
            se="pandeykedarnath18200@gmail.com"
            re=email
            pw="Shubh2018@4662"
            message="SHUBHAM  METACOMPANY \n You are registered with SAHAJ ROJGAR"
            sr=smtplib.SMTP('smtp.gmail.com', 587)
            sr.starttls()
            sr.login(se,pw)
            print("LOG IN SUCCESS")
            sr.sendmail(se, re, message)
            print("sent ",re)                
             #sfsfsdgfyhsfgshyfgshuff
            mb.showinfo("☑️ STATUS","👉🏽 Namaste 🙏"+full_name.title()+" Restration Successful !!!! \n 👉🏽 Kindly ✔️ Log_In")
    # BUTTON ==>
    submit=tk.Button(wind,text="👍🏾 REGISTER",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=action)
    submit.grid(row=11,column=0,padx=3, pady=30)
    mb.showinfo("🗣 carefull".upper()," 🧓🏻 NAME LIKE ABC \n".title()
           +" 🆎 E-MAIL BE LIKE abc@gmail.com \n".title()+" ☏ CONTACT BE LIKE 7522035457 \n".title()
           +" 🌏 ADDRESS BE LIKE VILL, TEHSIL,  DISTRICT".title())
#####################################################

submit=tk.Button(win,text="📕Register",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=register)
submit.grid(row=5,column=0,sticky=tk.W,padx=250,pady=60)
win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-16f8aa7221c1>", line 429, in action
#     sr.login(se,pw)
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 734, in login
#     raise last_exception
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 723, in login
#     (code, resp) = self.auth(
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 646, in auth
#     raise SMTPAuthenticationError(code, resp)
# smtplib.SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials x13sm3278700pja.3 - gsmtp')

# %%
# EMPLOYEE RECURIMENT SYSTEM  4662 done 👍🏾  ====>>>
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox as mb
from csv import DictWriter as d_w
from csv import DictReader as d_r
import os
import datetime
import random as rd
win=tk.Tk()
win.title("✔️ Log_In")
win.configure(background="orange")
win.geometry("500x400+50+50")
win.resizable(0,0)
#to add image====>
file=tk.PhotoImage(file="2.gif")
quote=tk.Label(win,image=file,height=160,width=300,borderwidth=8,relief="raised")
quote.grid(row=0,column=0,sticky=tk.W,padx=70,pady=5)
quote1=tk.Label(win,text="SHUBHAM METACOMPANY",height=1,width=40,borderwidth=8,relief='groove',font=("Apple Chancery",20),foreground="red")
quote1.grid(row=0,column=0,sticky=tk.W,padx=7)
# LABEL =>
lname=tk.StringVar()
lname=ttk.Label(win,text="🆎 USERNAME",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=15 )
lname.grid(row=2, column=0, sticky=tk.W,pady=8,padx=2)
# ENTERY =>
lname_var=tk.StringVar()
lname_entery=tk.Entry(win,textvariable=lname_var,font=("Rockwell",15),borderwidth=8,relief="sunken")
lname_entery.grid(row=4,column=0,sticky=tk.W,padx=19)
lname_entery.focus()
# LABEL =>
lpassword=ttk.Label(win,text="🔐 PASSWORD",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=15 )
lpassword.grid(row=2, column=0, sticky=tk.W,pady=8,padx=303)
# ENTERY =>
lpassword_var=tk.StringVar()
lpassword_entery=tk.Entry(win,textvariable=lpassword_var,font=("Rockwell",15),borderwidth=8,relief="sunken")
lpassword_entery.grid(row=4,column=0,sticky=tk.W,padx=270)
#msg box ==>
mb.showinfo("🗣 carefull".upper(),"👉🏽 username".title()+" is Your Name  \n"+"👉🏽 password is your contact number".title())
# BUTTON ==>
def login():
    flname=lname_var.get().upper()
    flpassword=lpassword_var.get()
    if flname=="" or flpassword=="":
        mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
    else:
        lpassword_entery.delete(0,tk.END)
        lpassword_entery.focus()
        #read from csv==>
        with open('register.csv','r') as fi:
            c=d_r(fi)
            l=False
            for row in c:
                if row['NAME']==flname and row['PASSWORD']==flpassword:
                    mb.showinfo("☑️ STATUS","Namaste 🙏 "+flname +" Log-In Successful !!!! ")
                    l=True
                     #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
                     # MAIN WINDOW ===>
                    top2=tk.Toplevel()
                    top2.title(" 🇮🇳 COUNTRY FIRST 🛠 SHUBHAM METACOMPANY")
                    top2.configure(background="orange")
                    top2.geometry("1200x670+50+0")
                    top2.resizable(0,0)
                    #file=tk.PhotoImage(file="2.gif")
                    vote=tk.Label(top2,image=file,height=160,width=300,borderwidth=8,relief="raised")
                    vote.grid(row=0,column=0,sticky=tk.W,padx=420,pady=5)
                    quote2=tk.Label(top2,text="⛪️   SHUBHAM METACOMPANY   🛠",height=1,width=70,borderwidth=8,relief='groove',font=("Apple Chancery",30),foreground="red")
                    quote2.grid(row=0,column=0,sticky=tk.W,padx=7)
                     # LABEL left===>
                    name=tk.Label(top2,text="🧰 सहज रोजगार ", font=("Rockwell",30),width=20,height=2,borderwidth=8,relief='raised')
                    name.grid(row=1,column=0,sticky=tk.W, pady=100)
                    name=tk.Label(top2,text="🧑‍🦰 WELCOME "+flname, font=("Rockwell",15),width=30,height=1,borderwidth=8,relief='raised')
                    name.grid(row=1,column=0,sticky=tk.W,padx=850, pady=40)
                    #aplly button coded==>
                    def KEYG():
                        top7=tk.Toplevel()
                        top7.title(" 🇮🇳 COUNTRY FIRST 🛠 SHUBHAM METACOMPANY")
                        top7.configure(background="orange")
                        top7.geometry("500x400+50+50")
                        top7.resizable(0,0)
                        la1=tk.Label(top7,text="APPLICATION FORM",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=35 )
                        la1.grid(row=0,column=0,sticky=tk.W,padx=5,pady=5)
                         # LABEL =>
                        lname1=ttk.Label(top7,text="🌴 YOUR EMAIL",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname1.grid(row=1, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var1=tk.StringVar()
                        lname_entery1=tk.Entry(top7,textvariable=lname_var1,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery1.grid(row=1,column=0,sticky=tk.W,pady=5,padx=260)
                        lname_entery1.focus()
                         # LABEL =>
                        lname2=tk.StringVar()
                        lname2=ttk.Label(top7,text="🚩 COMPANY EMAIL",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname2.grid(row=2, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var2=tk.StringVar()
                        lname_entery2=tk.Entry(top7,textvariable=lname_var2,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery2.grid(row=2,column=0,sticky=tk.W,padx=260)
                         # LABEL =>
                        lname3=ttk.Label(top7,text=" 📌 JOB - ID",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname3.grid(row=3, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        job_id_var1 =tk.StringVar()
                        job_id_var1=tk.Entry(top7,textvariable=job_id_var1,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        job_id_var1.grid(row=3,column=0,sticky=tk.W,padx=260)
                        # LABEL =>
                        lname4=tk.StringVar()
                        lname4=ttk.Label(top7,text=" 📕 POST",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                        lname4.grid(row=4, column=0, sticky=tk.W,pady=5,padx=2)
                         # ENTERY =>
                        lname_var4=tk.StringVar()
                        lname_entery4=tk.Entry(top7,textvariable=lname_var4,font=("Rockwell",15),borderwidth=8,relief="sunken")
                        lname_entery4.grid(row=4,column=0,sticky=tk.W,padx=260) 
                         #button
                        def app():
                            cemail=lname_var2.get()   #recieve address
                            semail=lname_var1.get()   #sender email
                            jobid1=job_id_var1.get()
                            post1=lname_var4.get()
                            import re
                            regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
                            a=cemail
                            b=False
                            if(re.search(regex,a)):
                                b=True
                            else:
                                b="fail"
                            if cemail=="" or semail=="" or jobid1=="" or post1=="":
                                mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
                            elif b=="fail":
                                mb.showerror("⚠️ ERROR","such email-id does not exist !!! ".title())
                            else:
                                from email.message import EmailMessage
                                import os
                                import smtplib
                                import imghdr
                                from tkinter import filedialog as fd
                                eid="pandeykedarnath18200@gmail.com"
                                epass="Shubh2018@4662"
                                b=fd.askopenfile(initialdir="/")
                                c=b.name
                                str(c)
                                msg=EmailMessage()
                                msg['subject']="Job Application"
                                msg['from']="pandeykedarnath18200@gmail.com"
                                msg['to']=str(cemail)
                                msg.set_content("Sir kindly accept my resume for my job profile \n REPLY => "+semail +" \n JOB-ID => " + jobid1 + "\nPOST => "+ post1)
                                with open(c,'rb') as m:
                                    file_data=m.read()
                                    file_type=imghdr.what(m.name)
                                    file_name=m.name
                                msg.add_attachment(file_data,maintype='image',subtype=file_type,filename=file_name)
                                with smtplib.SMTP_SSL('smtp.gmail.com',465) as smtp:
                                    smtp.login(eid,epass)
                                    print("log success")
                                    smtp.send_message(msg)
                                    print("sent")
                                    import mysql.connector
                                    conn=mysql.connector.connect(host="localhost",username="root",password="shubh2017@4662",database="job_applied")
                                    my_cursor=conn.cursor()
                                     #query="CREATE TABLE job (SENDER_EMAIL varchar(50), COMPANY_EMAIL varchar(50),JOB_ID varchar(20),POST varchar(50))"
                                    query="INSERT INTO job(SENDER_EMAIL, COMPANY_EMAIL, JOB_ID, POST) VALUES(%s, %s, %s, %s)"
                                    values=(semail,cemail,jobid1,post1)
                                    my_cursor.execute(query,values)
                                     #print(my_cursor.fetchall())
                                    conn.commit()
                                    conn.close()
                                    mb.showinfo("🖌 STATUS", "Job 🗂 Applied \n Recruiter 🕵️‍♀️Will Contact Soon Via E-Mail")                      
                        but1=tk.Button(top7,text="Upload 🎬 Resume & Apply",width=40,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",15),command=app)
                        but1.grid(row=5,column=0,sticky=tk.W,pady=10,padx=30)
                        # view applied jobs 
                        def app1():
                            top8=tk.Toplevel()
                            top8.title(" 🇮🇳 COUNTRY FIRST 🛠 SHUBHAM METACOMPANY")
                            top8.configure(background="orange")
                            top8.geometry("500x400+50+50")
                            #top8.resizable(0,0)
                            la1=tk.Label(top8,text="APPLICATION FORM",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=35 )
                            la1.grid(row=0,column=0,sticky=tk.W,padx=5,pady=5)
                            # LABEL =>
                            lname1=ttk.Label(top8,text="🌴 YOUR EMAIL",foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20),width=20 )
                            lname1.grid(row=1, column=0, sticky=tk.W,pady=5,padx=2)
                             # ENTERY =>
                            vname_var1=tk.StringVar()
                            vname_entery1=tk.Entry(top8,width=22,textvariable=vname_var1,font=("Rockwell",15),borderwidth=8,relief="sunken")
                            vname_entery1.grid(row=1,column=0,sticky=tk.W,pady=5,padx=260)
                            vname_entery1.focus()
                            #view ==>
                            def app2():
                                lis=[]
                                g1=vname_var1.get()
                                import mysql.connector
                                conn=mysql.connector.connect(host="localhost",username="root",password="shubh2017@4662",database="job_applied")
                                my_cursor=conn.cursor()
                                #query="CREATE TABLE job (SENDER_EMAIL varchar(50), COMPANY_EMAIL varchar(50),JOB_ID varchar(20),POST varchar(50))"
                                query="SELECT* FROM job"
                                my_cursor.execute(query)
                                result=my_cursor.fetchall()
                                for i in result:
                                    if i[0]==g1:
                                        lis+="JOB_ID==>"+i[2]+","
                                        lis+="POST==>" +i[3]+"||"
                                conn.commit()
                                conn.close()
                                lf1=tk.LabelFrame(top8, text=lis, width=500, height=400)
                                lf1.grid(row=2, column=0,sticky=tk.W,padx=0,pady=10)                            
                                #lname1=tk.Label(lf1,text=lis,foreground="blue",borderwidth=8,relief="raised",font=("Rockwell",20))
                                #lname1.grid(row=1, column=0, sticky=tk.W,pady=5,padx=2)
                            butv=tk.Button(top8,text="  View🎗",width=40,foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",15),command=app2)
                            butv.grid(row=2,column=0,sticky=tk.W,pady=10,padx=30)
                        butw=tk.Button(top7,text="View🎗 Applied Job",width=40,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",15),command=app1)
                        butw.grid(row=6,column=0,sticky=tk.W,pady=10,padx=30)
                    apply=tk.Button(top2,text="APLLY ✍🏻 JOB".title(),height=1,width=15,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",20),command=KEYG)
                    apply.grid(row=1,column=0,sticky=tk.W,padx=510,pady=100)
                     ############################################################
                     #button ===>
                    def post_job():
                        top1=tk.Toplevel()
                        top1.title("🏅 post a job".title())
                        top1.configure(background="orange")
                        top1.geometry("500x650+50+0")
                         #top1.resizable(0,0) 
                         # TITLE LABEL =>
                        title=tk.Label(top1,text="🔱 POST A JOB ",width=25,borderwidth=5,relief="sunken", font=("Apple Chancery",28))
                        title.grid(row=0,column=0,sticky=tk.W,padx=30, pady=5)
                        title.configure(foreground="red")
                         #LABEL ==>
                        label=['🏛 COMPANY', '🪑 POST','👨‍🎓 ELIGIBILITY','Ⓜ️ SALARY','☏ E-MAIL & Mob.','🧜‍ CATEGORY']
                        a=1
                        for i in range(len(label)): 
                            cur_l="label"+ str(i) #label 1, label2, etc
                            cur_l=tk.Label(top1, text=label[i],borderwidth=8,relief="raised",font=("Rockwell",20),width=20,height=2)
                            cur_l.grid(row=i+a, column=0, sticky=tk.W, padx=2,pady=5)
                            cur_l.configure(foreground="blue")
                            a+=1
                         #ENTERY==>
                        user_info1={
                                   'company':tk.StringVar(),
                                   'post':tk.StringVar(),
                                   'eligibility':tk.StringVar(),
                                   'salary':tk.StringVar(),    #var section
                                   'contact':tk.StringVar(),
                            }
                        a=1
                        j=0
                        for i in user_info1:
                            cur_entery='entery'+i   #enteryname, enteryaddress, etc
                            cur_entery=tk.Entry(top1, width=25,textvariable=user_info1[i], font=("Rockwell",15),borderwidth=8,relief="sunken")
                            cur_entery.grid(row=j+a, column=0,padx=240,)
                            cur_entery.configure(foreground="red")
                            a+=1
                            j+=1
                            if(i=='NAME'):
                                cur_entery.focus()
                         # COMBOBOX ==>
                        group_var=tk.StringVar()
                        group_entery=ttk.Combobox(top1,width=25,state='readonly',font=("Rockwell",15),textvariable=group_var)
                        group_entery['values']=('⌨️ data entery'.title(), '📞 back office'.title(),'🎥 iT sector'.title(),
                                                '📺 non technical'.title(),'💻 technical'.title(),'👮‍administrative'.title(),
                                                '⛏ grade d'.title(),'🔨 construction'.title(),'⚔️ trainer'.title())
                        group_entery.current(0)
                        group_entery.grid(row=11,column=0,padx=22) 
                        #____________________
                        mb.showinfo("🗣 carefull".upper()," 🧓🏻 COMPANY LIKE ABC \n".title()
                                    +" 🆎 POST BE LIKE director \n".title()+"👨‍🎓 eligibility BE LIke education/experience \n".title()
                                    +" 🌏 salary BE LIKE 45k p.A \n".title()+" 🌏 contact BE LIKE 7256362598 AND E-MAIL".title())
                          #BUTTON ACTION ===>
                        def post():
                            company_p= user_info1['company'].get().upper()
                            post_p= user_info1['post'].get().upper()
                            eligibility_p= user_info1['eligibility'].get().title()
                            salary_p= user_info1['salary'].get()
                            contact_p=user_info1['contact'].get()
                            categorey_p=group_var.get().title()
                            tday=datetime.date.today()                            
                            if company_p==""or post_p=="" or eligibility_p=="" or salary_p=="":
                                mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
                            else:
                                mb.showinfo("☑️ STATUS","Congratulations 🙏"+company_p+" Job Posted !!!! ")
                                #=================
                                def w():
                                    write=d_w(f,fieldnames=['COMPANY','JOB-ID','POST','ELIGIBILITY','SALARY','CONTACT','CATEGOREY','DATE'])
                                    if os.stat('CONSTRUCTION_JOBS.csv').st_size==0:
                                        write.writeheader()
                                    write.writerow({
                                                    'JOB-ID':rd.randint(1234,56789),
                                                    'COMPANY':company_p,
                                                    'POST':post_p,
                                                    'ELIGIBILITY':eligibility_p,
                                                    'SALARY':salary_p,
                                                    'CONTACT':contact_p,
                                                    'CATEGOREY':categorey_p,
                                                    'DATE':tday
                                       })           
                                #===================
                                #how to write with csv file===>
                                #=====================
                                if categorey_p=="⌨️ Data Entery":
                                    with open('DATA_ENTERY_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="📞 Back Office":
                                    with open('BACK_OFFICE_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="🎥 It Sector":
                                    with open('IT_SECTOR_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="📺 Non Technical":
                                    with open('NON_TECHNICAL_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="💻 Technical":
                                    with open('TECHNICAL_JOBS.csv','a') as f:
                                        w()                    
                                elif categorey_p=="👮‍Administrative":
                                    with open('ADMINISTRATIVE_JOBS.csv','a') as f:
                                        w()
                                elif categorey_p=="⛏ Grade D":
                                    with open('GRADE_D_JOBS.csv','a') as f:
                                        w()  
                                elif categorey_p=="🔨 Construction":
                                    with open('CONSTRUCTION_JOBS.csv','a') as f:
                                        w()
                                else:
                                    with open('TRAINER_JOBS.csv','a') as f:
                                        w()
                          # BUTTON ==>
                        submit_p=tk.Button(top1,text="👍🏾 POST",height=1,width=25,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=post)
                        submit_p.grid(row=12,column=0,sticky=tk.W,padx=100, pady=30)
                        #==================================================  
                    post_job=tk.Button(top2,text="POST JOB HERE  ➤".title(),height=1,width=15,background="black",foreground="blue",borderwidth="5",relief="raised",font=("Rockwell",20),command=post_job)
                    post_job.grid(row=1,column=0,sticky=tk.W,padx=290,pady=100)
                     #======================
                     #LAST KI BUTTON ====>
                     #===========================================
                    def KEYA():
                        os.system("open DATA_ENTERY_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 DATA ENTERY".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYA)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=3,pady=5)

                    def KEYB():
                        os.system("open BACK_OFFICE_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 BACK OFFICE ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYB)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=3,pady=5)

                    def KEYC():
                        os.system("open IT_SECTOR_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 IT SECTOR ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYC)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=3,pady=5)
                     #===========================================
                    def KEYD():
                        os.system("open NON_TECHNICAL_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 NON TECHNICAL ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYD)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=430,pady=0)

                    def KEYE():
                        os.system("open TECHNICAL_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 TECHNICAL ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYE)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=430,pady=5)

                    def KEYF():
                        os.system("open ADMINISTRATIVE_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 ADMINSTRATIVE".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYF)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=430,pady=5)
                    #============================================
                    def KEYG():
                        os.system("open GRADE_D_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 GRADE D".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYG)
                    post_job.grid(row=2,column=0,sticky=tk.W,padx=849,pady=0)

                    def KEYH():
                        os.system("open CONSTRUCTION_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 CONSTRUCTION ".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYH)
                    post_job.grid(row=3,column=0,sticky=tk.W,padx=849,pady=5)

                    def KEYI():
                        os.system("open TRAINER_JOBS.csv")
                    post_job=tk.Button(top2,text="💼 TRAINER".title(),height=1,width=25,background="black",foreground="RED",borderwidth="5",relief="raised",font=("Apple Chancery",20),command=KEYI)
                    post_job.grid(row=4,column=0,sticky=tk.W,padx=849,pady=5)                     
                    #@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
            if l==False:
                mb.showinfo("☑️ STATUS","Enter 🕹 correct details".title())
submit=tk.Button(win,text="✔️ Log-In",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=login)
submit.grid(row=5,column=0,sticky=tk.W,padx=30,pady=60)
######################### BUTTON REGISTRATON ===>
def register():
    wind=tk.Toplevel()
    wind.title("📓 REGISTER")
    wind.configure(background="orange")
    wind.geometry("305x600+570+50")
    wind.resizable(0,0)
    #to add image 
    # TITLE LABEL =>
    title=ttk.Label(wind,text="REGISTER HERE !!! ",borderwidth=5,relief="flat", font=("Apple Chancery",28))
    title.grid(row=0,column=0, pady=5)
    title.configure(background="blue",foreground="red")
    #LABEL ==>
    label=['🧓🏻 FULL NAME', '🆎 E-MAIL', '☏ CONTACT','🗝 PASSWORD','🧜‍ GENDER']
    a=1
    for i in range(len(label)):
        cur_l="label"+ str(i) #label 1, label2, etc
        cur_l=ttk.Label(wind, text=label[i],borderwidth=8,relief="raised",font=("Rockwell",20),width=15)
        cur_l.grid(row=i+a, column=0, sticky=tk.W, padx=2,pady=5)
        cur_l.configure(foreground="blue")
        a+=1
    #ENTERY==>
    user_info={
        'NAME':tk.StringVar(),
        'E-MAIL':tk.StringVar(),
        'CONTACT':tk.StringVar(),
        'PASSWORD':tk.StringVar(),    #var section
      }
    c=2
    j=0
    for i in user_info:
        cur_entery='entery'+i   #enteryname, enteryaddress, etc
        cur_entery=tk.Entry(wind, width=28,textvariable=user_info[i], font=("Rockwell",15),borderwidth=8,relief="sunken")
        cur_entery.grid(row=c+j, column=0,padx=24)
        cur_entery.configure(foreground="red")
        c+=1
        j+=1
        if(i=='NAME'):
            cur_entery.focus()
    # COMBOBOX ==>
    gender_var=tk.StringVar()
    gender=ttk.Combobox(wind,width=28,state='readonly',font=("Rockwell",15),textvariable=gender_var)
    gender['values']=('Male', 'Female','Other')
    gender.current(0)
    gender.grid(row=10,column=0,padx=22)
    #BUTTON ACTION ===>
    def action():
        full_name= user_info['NAME'].get().upper()
        email= user_info['E-MAIL'].get()
        contact= user_info['CONTACT'].get()
        str(contact)
        password= user_info['PASSWORD'].get()
        gender=gender_var.get().title()
        import re
        regex = '^[a-z0-9]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$'
        a=email
        b=False
        if(re.search(regex,a)):
            b=True
        else:
            b="fail"
        if full_name==""or email=="" or contact=="" or password=="":
            mb.showerror("⚠️ ERROR","please 👉🏽 fill all the fields".title())
        elif full_name.isdigit()==True or contact.isdigit()==False:
            mb.showwarning("☠️ WARNING ", "👉🏽 name 🗣 must be alphabatic \n 👉🏽 contact must be numeric".title())
        elif b=="fail":
            mb.showerror("⚠️ ERROR","INVALID EMAIL")
        else:            
            #how to write with csv file===>
            with open('register.csv','a') as f:
                write=d_w(f,fieldnames=['NAME','EMAIL','CONTACT','PASSWORD','GENDER'])
                if os.stat('register.csv').st_size==0:
                    write.writeheader()
                write.writerow({
                    'NAME':full_name,
                    'EMAIL':email,
                    'CONTACT':contact,
                    'PASSWORD':password,
                    'GENDER':gender
                  })
            cur_entery.delete(0,tk.END)
             #mail after regist 
            import smtplib
            se="pandeykedarnath18200@gmail.com"
            re=email
            pw="Shubh2018@4662"
            message="SHUBHAM  METACOMPANY \n You are registered with SAHAJ ROJGAR"
            sr=smtplib.SMTP('smtp.gmail.com', 587)
            sr.starttls()
            sr.login(se,pw)
            print("LOG IN SUCCESS")
            sr.sendmail(se, re, message)
            print("sent ",re)                
             #sfsfsdgfyhsfgshyfgshuff
            mb.showinfo("☑️ STATUS","👉🏽 Namaste 🙏"+full_name.title()+" Restration Successful !!!! \n 👉🏽 Kindly ✔️ Log_In")
    # BUTTON ==>
    submit=tk.Button(wind,text="👍🏾 REGISTER",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=action)
    submit.grid(row=11,column=0,padx=3, pady=30)
    mb.showinfo("🗣 carefull".upper()," 🧓🏻 NAME LIKE ABC \n".title()
           +" 🆎 E-MAIL BE LIKE abc@gmail.com \n".title()+" ☏ CONTACT BE LIKE 7522035457 \n".title()
           +" 🌏 ADDRESS BE LIKE VILL, TEHSIL,  DISTRICT".title())
#####################################################

submit=tk.Button(win,text="📕Register",height=1,width=15,bg="blue",foreground="red",borderwidth="5",relief="groove",font=("Apple Chancery",20),command=register)
submit.grid(row=5,column=0,sticky=tk.W,padx=250,pady=60)
win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-4-ad331e858d7a>", line 471, in action
#     sr.login(se,pw)
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 734, in login
#     raise last_exception
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 723, in login
#     (code, resp) = self.auth(
#   File "/Users/shubhampandey/opt/anaconda3/lib/python3.8/smtplib.py", line 646, in auth
#     raise SMTPAuthenticationError(code, resp)
# smtplib.SMTPAuthenticationError: (535, b'5.7.8 Username and Password not accepted. Learn more at\n5.7.8  https://support.google.com/mail/?p=BadCredentials a16sm132587pgl.12 - gsmtp')
# LOG IN SUCCESS
# sent  pandeyshubham182000@gmail.com
# Exception in Tkinter callback
# Traceback (most recent call last):
# ...
